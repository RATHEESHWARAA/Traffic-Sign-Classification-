# %% [markdown]
# ### **Import Libraries**

# %%
import keras
from keras.models import Sequential
from keras.layers.convolutional import Conv2D ,MaxPooling2D
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import pickle
import pandas as pd
import numpy as np
import random
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### **Import Dataset and Explore it**

# %%
# cloning repo containing the traffic sign dataset
# !git clone https://bitbucket.org/jadslim/german-traffic-signs
# Out:
# Cloning into 'german-traffic-signs'...
# remote: Counting objects: 6, done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 6 (delta 0), reused 0 (delta 0)
# Unpacking objects: 100% (6/6), done.

# %%
# list dataset contents
 
# !ls german-traffic-signs
# Out:
# signnames.csv  test.p  train.p	valid.p

# %%
#load the dataset

data = pd.read_csv('german-traffic-signs/signnames.csv')

# %%
data
# Out:
#     ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %%
#loading pickled dataset

with open("german-traffic-signs/train.p",mode='rb') as training:
  train = pickle.load(training)

with open("german-traffic-signs/valid.p",mode='rb') as validation:
  valid = pickle.load(validation)

with open("german-traffic-signs/test.p",mode='rb') as testing:
  test = pickle.load(testing)

# %%
X_train , y_train = train['features'], train['labels']
X_validation , y_validation = valid['features'], valid['labels']
X_test , y_test = test['features'], test['labels']

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)
# Out:
# (34799, 32, 32, 3)
# (4410, 32, 32, 3)
# (12630, 32, 32, 3)

# %%
index = np.random.randint(1,len(X_train))
plt.imshow(X_train[index])
print("image label={}".format(y_train[index]))
# Out:
# image label=5

# %% [markdown]
# # Image Pre-processing

# %% [markdown]
# ### 1. Converting to grayscale
# ### 2. Histogram Equalization
# ### 3. Normalization

# %%
# shuffle the data
from sklearn.utils import shuffle
X_train , y_train = shuffle(X_train,y_train)

# %%
def preprocessing(img): 
  #convert to grayscale
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  #Applying histogram equalization 
  img = cv2.equalizeHist(img)
  #Normalization
  img = img/255
  return img

# %%
X_train_processed = np.array(list(map(preprocessing,X_train)))
X_validation_processed = np.array(list(map(preprocessing,X_validation)))
X_test_processed = np.array(list(map(preprocessing,X_test)))

# %%
X_train_processed = X_train_processed.reshape(34799,32,32,1)
X_test_processed = X_test_processed.reshape(12630,32,32,1)
X_validation_processed = X_validation_processed.reshape(4410,32,32,1)

# %%
print(X_train_processed.shape)
print(X_test_processed.shape)
print(X_validation_processed.shape)
# Out:
# (34799, 32, 32, 1)
# (12630, 32, 32, 1)
# (4410, 32, 32, 1)

# %%
i= random.randint(1,len(X_train))
plt.imshow(X_train_processed[i].squeeze(),cmap='gray')
plt.figure()
plt.imshow(X_train[i].squeeze())

# %% [markdown]
# # Build Deep Convolution Neural Network Model

# %%
model = Sequential()
# add the convolutional layer
# filters, size of filters,input_shape,activation_function
model.add(Conv2D(32,(5,5),activation='relu',input_shape=(32,32,1)))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# place a dropout layer
model.add(Dropout(0.25))

# add another convolutional layer
model.add(Conv2D(64,(5,5),activation='relu'))

# pooling layer
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten the image to 1 dimensional array
model.add(Flatten())

# add a dense layer : amount of nodes, activation
model.add(Dense(256,activation='relu'))

# place a dropout layer
# 0.5 drop out rate is recommended, half input nodes will be dropped at each update
model.add(Dropout(0.5))

# defining the ouput layer of our network
model.add(Dense(43,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        51264
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               409856
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 473,003
# Trainable params: 473,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile our model
model.compile(Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_processed,
                    y_train,
                    batch_size=500,
                    epochs=50,
                    verbose=1,
                    validation_data=(X_validation_processed,y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/50
# 34799/34799 [==============================] - 8s 243us/step - loss: 3.5824 - accuracy: 0.0616 - val_loss: 3.4530 - val_accuracy: 0.2002
# Epoch 2/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 3.2380 - accuracy: 0.1776 - val_loss: 2.9461 - val_accuracy: 0.3517
# Epoch 3/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 2.6096 - accuracy: 0.3453 - val_loss: 2.2761 - val_accuracy: 0.4297
# Epoch 4/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 2.0999 - accuracy: 0.4414 - val_loss: 1.8384 - val_accuracy: 0.5177
# Epoch 5/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.7612 - accuracy: 0.5098 - val_loss: 1.5191 - val_accuracy: 0.6034
# Epoch 6/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.5161 - accuracy: 0.5659 - val_loss: 1.2880 - val_accuracy: 0.6703
# Epoch 7/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.3284 - accuracy: 0.6110 - val_loss: 1.1159 - val_accuracy: 0.7036
# Epoch 8/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.1866 - accuracy: 0.6497 - val_loss: 0.9910 - val_accuracy: 0.7315
# Epoch 9/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 1.0642 - accuracy: 0.6826 - val_loss: 0.8869 - val_accuracy: 0.7662
# Epoch 10/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.9760 - accuracy: 0.7094 - val_loss: 0.7972 - val_accuracy: 0.7914
# Epoch 11/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.8892 - accuracy: 0.7335 - val_loss: 0.7348 - val_accuracy: 0.8050
# Epoch 12/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.8271 - accuracy: 0.7512 - val_loss: 0.6717 - val_accuracy: 0.8238
# Epoch 13/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.7641 - accuracy: 0.7720 - val_loss: 0.6420 - val_accuracy: 0.8188
# Epoch 14/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.7178 - accuracy: 0.7864 - val_loss: 0.6061 - val_accuracy: 0.8302
# Epoch 15/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.6678 - accuracy: 0.7993 - val_loss: 0.5584 - val_accuracy: 0.8447
# Epoch 16/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.6194 - accuracy: 0.8165 - val_loss: 0.5342 - val_accuracy: 0.8463
# Epoch 17/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.5895 - accuracy: 0.8229 - val_loss: 0.5063 - val_accuracy: 0.8596
# Epoch 18/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.5518 - accuracy: 0.8361 - val_loss: 0.4907 - val_accuracy: 0.8574
# Epoch 19/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.5239 - accuracy: 0.8446 - val_loss: 0.4643 - val_accuracy: 0.8664
# Epoch 20/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.4965 - accuracy: 0.8514 - val_loss: 0.4441 - val_accuracy: 0.8746
# Epoch 21/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4720 - accuracy: 0.8594 - val_loss: 0.4311 - val_accuracy: 0.8753
# Epoch 22/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4482 - accuracy: 0.8663 - val_loss: 0.4184 - val_accuracy: 0.8764
# Epoch 23/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4298 - accuracy: 0.8713 - val_loss: 0.4059 - val_accuracy: 0.8819
# Epoch 24/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.4107 - accuracy: 0.8787 - val_loss: 0.3886 - val_accuracy: 0.8878
# Epoch 25/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3884 - accuracy: 0.8854 - val_loss: 0.3737 - val_accuracy: 0.8916
# Epoch 26/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3780 - accuracy: 0.8870 - val_loss: 0.3648 - val_accuracy: 0.8952
# Epoch 27/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3604 - accuracy: 0.8926 - val_loss: 0.3521 - val_accuracy: 0.8980
# Epoch 28/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3482 - accuracy: 0.8956 - val_loss: 0.3476 - val_accuracy: 0.8993
# Epoch 29/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3317 - accuracy: 0.9030 - val_loss: 0.3372 - val_accuracy: 0.9050
# Epoch 30/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3206 - accuracy: 0.9042 - val_loss: 0.3370 - val_accuracy: 0.9016
# Epoch 31/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.3076 - accuracy: 0.9090 - val_loss: 0.3261 - val_accuracy: 0.9052
# Epoch 32/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2937 - accuracy: 0.9143 - val_loss: 0.3114 - val_accuracy: 0.9104
# Epoch 33/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2833 - accuracy: 0.9148 - val_loss: 0.3149 - val_accuracy: 0.9118
# Epoch 34/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.2751 - accuracy: 0.9195 - val_loss: 0.3052 - val_accuracy: 0.9125
# Epoch 35/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2673 - accuracy: 0.9201 - val_loss: 0.3067 - val_accuracy: 0.9093
# Epoch 36/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2547 - accuracy: 0.9260 - val_loss: 0.2926 - val_accuracy: 0.9177
# Epoch 37/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2450 - accuracy: 0.9279 - val_loss: 0.2919 - val_accuracy: 0.9166
# Epoch 38/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2447 - accuracy: 0.9284 - val_loss: 0.2849 - val_accuracy: 0.9159
# Epoch 39/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.2360 - accuracy: 0.9291 - val_loss: 0.2813 - val_accuracy: 0.9177
# Epoch 40/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2261 - accuracy: 0.9321 - val_loss: 0.2758 - val_accuracy: 0.9177
# Epoch 41/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2181 - accuracy: 0.9356 - val_loss: 0.2688 - val_accuracy: 0.9211
# Epoch 42/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2123 - accuracy: 0.9389 - val_loss: 0.2656 - val_accuracy: 0.9224
# Epoch 43/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.2062 - accuracy: 0.9396 - val_loss: 0.2681 - val_accuracy: 0.9254
# Epoch 44/50
# 34799/34799 [==============================] - 2s 60us/step - loss: 0.2008 - accuracy: 0.9419 - val_loss: 0.2621 - val_accuracy: 0.9231
# Epoch 45/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1922 - accuracy: 0.9437 - val_loss: 0.2535 - val_accuracy: 0.9283
# Epoch 46/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1894 - accuracy: 0.9431 - val_loss: 0.2490 - val_accuracy: 0.9277
# Epoch 47/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1820 - accuracy: 0.9482 - val_loss: 0.2449 - val_accuracy: 0.9283
# Epoch 48/50
# 34799/34799 [==============================] - 2s 62us/step - loss: 0.1812 - accuracy: 0.9467 - val_loss: 0.2459 - val_accuracy: 0.9281
# Epoch 49/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1747 - accuracy: 0.9490 - val_loss: 0.2410 - val_accuracy: 0.9295
# Epoch 50/50
# 34799/34799 [==============================] - 2s 61us/step - loss: 0.1689 - accuracy: 0.9507 - val_loss: 0.2427 - val_accuracy: 0.9288

# %% [markdown]
# # Evaluate Performance of the model

# %%
score = model.evaluate(X_test_processed,y_test)
print('Test accuracy',score[1])
# Out:
# 12630/12630 [==============================] - 1s 109us/step
# Test accuracy 0.9151227474212646

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training','validation'])
plt.title('Training and validation losses')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training','validation'])
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
prediction = model.predict_classes(X_test_processed)
y_true_label= y_test

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_true_label,prediction)
plt.figure(figsize=(20,20))
sns.heatmap(matrix,annot=True)

# %%
L=6
W=6
fig , axes = plt.subplots(L,W,figsize=(12,12))
axes = axes.ravel()
for i in range(0,L*W):
  axes[i].imshow(X_test[i])
  axes[i].set_title('Prediction ={}\n True={}'.format(prediction[i],y_true_label[i]))
  axes[i].axis('off')
plt.subplots_adjust(wspace=1)

# %%
model.save('my_model.h5')
